# %%
import yfinance as yf
import pandas as pd
import openpyxl


a = pd.read_excel("../0056原始成分股.xlsx")

# %%
a.shape
# Out:
# (58, 51)

# %%
import numpy as np
a.reset_index(drop=True)
a.columns = np.arange(0, a.shape[1])

# %%
a_filter1 = a.iloc[5:, :]
a_filter1.reset_index(drop=True)
a_filter1.set_index()
# Out:
#      0      1       2          3       4               5       6      7   \
# 0   NaN   2023     NaN        NaN     NaN             NaN     NaN    NaN
# 1   NaN     Q4     NaN         Q3     NaN              Q2     NaN     Q1
# 2     1    聯發科  0.0342         亞泥  0.0183              亞泥  0.0224     亞泥
# 3     2     宏碁  0.0303         台塑  0.0152              台塑  0.0171     台塑
# 4     3     聯電  0.0301         南亞  0.0143              南亞  0.0158     南亞
# 5     4     聯詠  0.0300        遠東新  0.0160             遠東新  0.0196    遠東新
# 6     5     仁寶  0.0294         聚陽  0.0149              聚陽  0.0159     台玻
# 7     6     華碩  0.0292        永豐餘  0.0105             永豐餘  0.0122   東和鋼鐵
# 8     7     和碩  0.0276       東和鋼鐵  0.0082            東和鋼鐵  0.0095    大成鋼
# 9     8    大聯大  0.0262        大成鋼  0.0170             大成鋼  0.0180    興富發
# 10    9     群光  0.0252        興富發  0.0106             興富發  0.0117     遠雄
# 11   10     微星  0.0251         遠雄  0.0083              遠雄  0.0096     長榮
# ...
